# %%
from tvm import relay
from tvm.relay import testing
import tvm

# %%
resnet18_mod, resnet18_params = relay.testing.resnet.get_workload(num_layers=18)

with relay.build_config(opt_level=0):
    graph, lib, params = relay.build_module.build(resnet18_mod, "llvm", params=resnet18_params)
# Out:
# One or more operators have not been tuned. Please tune your model for better performance. Use DEBUG logging level to see more details.
# /home/wjh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: legacy graph executor behavior of producing json / lib / params will be removed in the next release. Please see documents of tvm.contrib.graph_executor.GraphModule for the  new recommended usage.
#   after removing the cwd from sys.path.

# %%
# print relay ir
print(resnet18_mod.astext(show_meta_data=False))
# Out:
# #[version = "0.0.5"]
# def @main(%data: Tensor[(1, 3, 224, 224), float32] /* ty=Tensor[(1, 3, 224, 224), float32] */, %bn_data_gamma: Tensor[(3), float32] /* ty=Tensor[(3), float32] */, %bn_data_beta: Tensor[(3), float32] /* ty=Tensor[(3), float32] */, %bn_data_moving_mean: Tensor[(3), float32] /* ty=Tensor[(3), float32] */, %bn_data_moving_var: Tensor[(3), float32] /* ty=Tensor[(3), float32] */, %conv0_weight: Tensor[(64, 3, 7, 7), float32] /* ty=Tensor[(64, 3, 7, 7), float32] */, %bn0_gamma: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %bn0_beta: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %bn0_moving_mean: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %bn0_moving_var: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn1_gamma: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn1_beta: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn1_moving_mean: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn1_moving_var: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_conv1_weight: Tensor[(64, 64, 3, 3), float32] /* ty=Tensor[(64, 64, 3, 3), float32] */, %stage1_unit1_bn2_gamma: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn2_beta: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn2_moving_mean: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_bn2_moving_var: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit1_conv2_weight: Tensor[(64, 64, 3, 3), float32] /* ty=Tensor[(64, 64, 3, 3), float32] */, %stage1_unit1_sc_weight: Tensor[(64, 64, 1, 1), float32] /* ty=Tensor[(64, 64, 1, 1), float32] */, %stage1_unit2_bn1_gamma: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_bn1_beta: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_bn1_moving_mean: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_bn1_moving_var: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_conv1_weight: Tensor[(64, 64, 3, 3), float32] /* ty=Tensor[(64, 64, 3, 3), float32] */, %stage1_unit2_bn2_gamma: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_bn2_beta: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_bn2_moving_mean: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_bn2_moving_var: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage1_unit2_conv2_weight: Tensor[(64, 64, 3, 3), float32] /* ty=Tensor[(64, 64, 3, 3), float32] */, %stage2_unit1_bn1_gamma: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage2_unit1_bn1_beta: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage2_unit1_bn1_moving_mean: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage2_unit1_bn1_moving_var: Tensor[(64), float32] /* ty=Tensor[(64), float32] */, %stage2_unit1_conv1_weight: Tensor[(128, 64, 3, 3), float32] /* ty=Tensor[(128, 64, 3, 3), float32] */, %stage2_unit1_bn2_gamma: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit1_bn2_beta: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit1_bn2_moving_mean: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit1_bn2_moving_var: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit1_conv2_weight: Tensor[(128, 128, 3, 3), float32] /* ty=Tensor[(128, 128, 3, 3), float32] */, %stage2_unit1_sc_weight: Tensor[(128, 64, 1, 1), float32] /* ty=Tensor[(128, 64, 1, 1), float32] */, %stage2_unit2_bn1_gamma: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit2_bn1_beta: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit2_bn1_moving_mean: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit2_bn1_moving_var: Tensor[(128), float32] /* ty=Tensor[(128), float32] */, %stage2_unit2_conv1_weight: Tensor[(128, 128, 3, 3), float32] /* ty=Tensor[(128, 128, 3, 3), float32] */, %stage2_unit2_bn2_gamma: Tensor[(128), f ...
#   %0 = nn.batch_norm(%data, %bn_data_gamma, %bn_data_beta, %bn_data_moving_mean, %bn_data_moving_var, epsilon=2e-05f, scale=False) /* ty=(Tensor[(1, 3, 224, 224), float32], Tensor[(3), float32], Tensor[(3), float32]) */;
#   %1 = %0.0 /* ty=Tensor[(1, 3, 224, 224), float32] */;
#   %2 = nn.conv2d(%1, %conv0_weight, strides=[2, 2], padding=[3, 3, 3, 3], channels=64, kernel_size=[7, 7]) /* ty=Tensor[(1, 64, 112, 112), float32] */;
#   %3 = nn.batch_norm(%2, %bn0_gamma, %bn0_beta, %bn0_moving_mean, %bn0_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 64, 112, 112), float32], Tensor[(64), float32], Tensor[(64), float32]) */;
#   %4 = %3.0 /* ty=Tensor[(1, 64, 112, 112), float32] */;
#   %5 = nn.relu(%4) /* ty=Tensor[(1, 64, 112, 112), float32] */;
#   %6 = nn.max_pool2d(%5, pool_size=[3, 3], strides=[2, 2], padding=[1, 1, 1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %7 = nn.batch_norm(%6, %stage1_unit1_bn1_gamma, %stage1_unit1_bn1_beta, %stage1_unit1_bn1_moving_mean, %stage1_unit1_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) */;
#   %8 = %7.0 /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %9 = nn.relu(%8) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %10 = nn.conv2d(%9, %stage1_unit1_conv1_weight, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %11 = nn.batch_norm(%10, %stage1_unit1_bn2_gamma, %stage1_unit1_bn2_beta, %stage1_unit1_bn2_moving_mean, %stage1_unit1_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) */;
#   %12 = %11.0 /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %13 = nn.relu(%12) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %14 = nn.conv2d(%13, %stage1_unit1_conv2_weight, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %15 = nn.conv2d(%9, %stage1_unit1_sc_weight, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %16 = add(%14, %15) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %17 = nn.batch_norm(%16, %stage1_unit2_bn1_gamma, %stage1_unit2_bn1_beta, %stage1_unit2_bn1_moving_mean, %stage1_unit2_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) */;
#   %18 = %17.0 /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %19 = nn.relu(%18) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %20 = nn.conv2d(%19, %stage1_unit2_conv1_weight, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %21 = nn.batch_norm(%20, %stage1_unit2_bn2_gamma, %stage1_unit2_bn2_beta, %stage1_unit2_bn2_moving_mean, %stage1_unit2_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) */;
#   %22 = %21.0 /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %23 = nn.relu(%22) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %24 = nn.conv2d(%23, %stage1_unit2_conv2_weight, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %25 = add(%24, %16) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %26 = nn.batch_norm(%25, %stage2_unit1_bn1_gamma, %stage2_unit1_bn1_beta, %stage2_unit1_bn1_moving_mean, %stage2_unit1_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 64, 56, 56), float32], Tensor[(64), float32], Tensor[(64), float32]) */;
#   %27 = %26.0 /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %28 = nn.relu(%27) /* ty=Tensor[(1, 64, 56, 56), float32] */;
#   %29 = nn.conv2d(%28, %stage2_unit1_conv1_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %30 = nn.batch_norm(%29, %stage2_unit1_bn2_gamma, %stage2_unit1_bn2_beta, %stage2_unit1_bn2_moving_mean, %stage2_unit1_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) */;
#   %31 = %30.0 /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %32 = nn.relu(%31) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %33 = nn.conv2d(%32, %stage2_unit1_conv2_weight, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %34 = nn.conv2d(%28, %stage2_unit1_sc_weight, strides=[2, 2], padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %35 = add(%33, %34) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %36 = nn.batch_norm(%35, %stage2_unit2_bn1_gamma, %stage2_unit2_bn1_beta, %stage2_unit2_bn1_moving_mean, %stage2_unit2_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) */;
#   %37 = %36.0 /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %38 = nn.relu(%37) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %39 = nn.conv2d(%38, %stage2_unit2_conv1_weight, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %40 = nn.batch_norm(%39, %stage2_unit2_bn2_gamma, %stage2_unit2_bn2_beta, %stage2_unit2_bn2_moving_mean, %stage2_unit2_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) */;
#   %41 = %40.0 /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %42 = nn.relu(%41) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %43 = nn.conv2d(%42, %stage2_unit2_conv2_weight, padding=[1, 1, 1, 1], channels=128, kernel_size=[3, 3]) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %44 = add(%43, %35) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %45 = nn.batch_norm(%44, %stage3_unit1_bn1_gamma, %stage3_unit1_bn1_beta, %stage3_unit1_bn1_moving_mean, %stage3_unit1_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 128, 28, 28), float32], Tensor[(128), float32], Tensor[(128), float32]) */;
#   %46 = %45.0 /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %47 = nn.relu(%46) /* ty=Tensor[(1, 128, 28, 28), float32] */;
#   %48 = nn.conv2d(%47, %stage3_unit1_conv1_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %49 = nn.batch_norm(%48, %stage3_unit1_bn2_gamma, %stage3_unit1_bn2_beta, %stage3_unit1_bn2_moving_mean, %stage3_unit1_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) */;
#   %50 = %49.0 /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %51 = nn.relu(%50) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %52 = nn.conv2d(%51, %stage3_unit1_conv2_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %53 = nn.conv2d(%47, %stage3_unit1_sc_weight, strides=[2, 2], padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %54 = add(%52, %53) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %55 = nn.batch_norm(%54, %stage3_unit2_bn1_gamma, %stage3_unit2_bn1_beta, %stage3_unit2_bn1_moving_mean, %stage3_unit2_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) */;
#   %56 = %55.0 /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %57 = nn.relu(%56) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %58 = nn.conv2d(%57, %stage3_unit2_conv1_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %59 = nn.batch_norm(%58, %stage3_unit2_bn2_gamma, %stage3_unit2_bn2_beta, %stage3_unit2_bn2_moving_mean, %stage3_unit2_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) */;
#   %60 = %59.0 /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %61 = nn.relu(%60) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %62 = nn.conv2d(%61, %stage3_unit2_conv2_weight, padding=[1, 1, 1, 1], channels=256, kernel_size=[3, 3]) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %63 = add(%62, %54) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %64 = nn.batch_norm(%63, %stage4_unit1_bn1_gamma, %stage4_unit1_bn1_beta, %stage4_unit1_bn1_moving_mean, %stage4_unit1_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 256, 14, 14), float32], Tensor[(256), float32], Tensor[(256), float32]) */;
#   %65 = %64.0 /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %66 = nn.relu(%65) /* ty=Tensor[(1, 256, 14, 14), float32] */;
#   %67 = nn.conv2d(%66, %stage4_unit1_conv1_weight, strides=[2, 2], padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %68 = nn.batch_norm(%67, %stage4_unit1_bn2_gamma, %stage4_unit1_bn2_beta, %stage4_unit1_bn2_moving_mean, %stage4_unit1_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) */;
#   %69 = %68.0 /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %70 = nn.relu(%69) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %71 = nn.conv2d(%70, %stage4_unit1_conv2_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %72 = nn.conv2d(%66, %stage4_unit1_sc_weight, strides=[2, 2], padding=[0, 0, 0, 0], channels=512, kernel_size=[1, 1]) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %73 = add(%71, %72) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %74 = nn.batch_norm(%73, %stage4_unit2_bn1_gamma, %stage4_unit2_bn1_beta, %stage4_unit2_bn1_moving_mean, %stage4_unit2_bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) */;
#   %75 = %74.0 /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %76 = nn.relu(%75) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %77 = nn.conv2d(%76, %stage4_unit2_conv1_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %78 = nn.batch_norm(%77, %stage4_unit2_bn2_gamma, %stage4_unit2_bn2_beta, %stage4_unit2_bn2_moving_mean, %stage4_unit2_bn2_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) */;
#   %79 = %78.0 /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %80 = nn.relu(%79) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %81 = nn.conv2d(%80, %stage4_unit2_conv2_weight, padding=[1, 1, 1, 1], channels=512, kernel_size=[3, 3]) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %82 = add(%81, %73) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %83 = nn.batch_norm(%82, %bn1_gamma, %bn1_beta, %bn1_moving_mean, %bn1_moving_var, epsilon=2e-05f) /* ty=(Tensor[(1, 512, 7, 7), float32], Tensor[(512), float32], Tensor[(512), float32]) */;
#   %84 = %83.0 /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %85 = nn.relu(%84) /* ty=Tensor[(1, 512, 7, 7), float32] */;
#   %86 = nn.global_avg_pool2d(%85) /* ty=Tensor[(1, 512, 1, 1), float32] */;
#   %87 = nn.batch_flatten(%86) /* ty=Tensor[(1, 512), float32] */;
#   %88 = nn.dense(%87, %fc1_weight, units=1000) /* ty=Tensor[(1, 1000), float32] */;
#   %89 = nn.bias_add(%88, %fc1_bias, axis=-1) /* ty=Tensor[(1, 1000), float32] */;
#   nn.softmax(%89) /* ty=Tensor[(1, 1000), float32] */
# }

# %%
# print source code
print(lib.get_source())
# Out:
# ; ModuleID = 'TVMMod'
# source_filename = "TVMMod"
# target datalayout = "e-m:e-p270:32:32-p271:32:32-p272:64:64-i64:64-f80:128-n8:16:32:64-S128"
# target triple = "x86_64-unknown-linux-gnu"
#
# %0 = type { double }
# %1 = type { ptr, %2, i32, %3, ptr, ptr, i64 }
# %2 = type { i32, i32 }
# %3 = type { i8, i8, i16 }
# %4 = type { ptr, i32 }
# %closure_loop_parallel_ax0.ax1.fused = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.0 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.1 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.2 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.3 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.4 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.5 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.6 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.7 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.8 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.9 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.10 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.11 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.12 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.13 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.14 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.15 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.16 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.17 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.18 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.19 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.20 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.21 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.22 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.23 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.24 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.25 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.26 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.27 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.28 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.29 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.30 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.31 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.32 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.33 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.34 = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.outer.35 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.36 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.37 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.38 = type { ptr, ptr }
# %closure_loop_parallel_bs.c.fused.h.fused = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.39 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.40 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.41 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.42 = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.43 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.44 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.45 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.46 = type { ptr, ptr, ptr }
# %closure_loop_parallel_bs.c.fused.h.fused.47 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.48 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.outer.fused = type { ptr, ptr, ptr }
# %closure_loop_parallel_bs.c.fused.h.fused.49 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.50 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.outer.fused.51 = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.52 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.53 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.54 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.55 = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.56 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.57 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.58 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.59 = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.60 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.61 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.outer.fused.62 = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.63 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.64 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.65 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.66 = type { ptr, ptr, ptr, i32 }
# %closure_loop_parallel_bs.c.fused.h.fused.67 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.68 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.69 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.70 = type { ptr, ptr, ptr }
# %closure_loop_parallel_bs.c.fused.h.fused.71 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.72 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.outer.fused.73 = type { ptr, ptr, ptr }
# %closure_loop_parallel_bs.c.fused.h.fused.74 = type { ptr, ptr }
# %closure_loop_parallel_i0.i1.fused.i2.fused.75 = type { ptr, ptr }
# %closure_loop_parallel_occ.k_h.fused.76 = type { ptr, ptr }
# %closure_loop_parallel_n.c.outer.fused.h.fused.77 = type { ptr, ptr, ptr }
# %closure_loop_parallel_x.outer.y.outer.fused = type { ptr, ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.78 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.79 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.80 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.81 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.82 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.83 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.84 = type { ptr, ptr }
# %closure_loop_parallel_ax0.ax1.fused.85 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.86 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.87 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.88 = type { ptr, ptr }
# %closure_loop_parallel_ax0.outer.89 = type { ptr, ptr }
#
# @__TVMAPISetLastError = linkonce dllexport local_unnamed_addr global ptr null, align 8
# @__TVMBackendParallelLaunch = linkonce dllexport local_unnamed_addr global ptr null, align 8
# @.str = private constant [77 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add: num_args should be 3\00", align 1
# @.str.1 = private constant [196 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add: Expect arg[0] to be pointer\00", align 1
# @.str.2 = private constant [196 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add: Expect arg[1] to be pointer\00", align 1
# @.str.3 = private constant [172 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add: Expect arg[2] to be pointer\00", align 1
# @.str.4 = private constant [107 x i8] c"Assert fail: (1 == tir.tvm_struct_get(arg.placeholder, 0, 4)), arg.placeholder.ndim is expected to equal 1\00", align 1
# @.str.5 = private constant [242 x i8] c"Assert fail: (((tir.tvm_struct_get(arg.placeholder, 0, 5) == (uint8)2) && (tir.tvm_struct_get(arg.placeholder, 0, 6) == (uint8)32)) && (tir.tvm_struct_get(arg.placeholder, 0, 7) == (uint16)1)), arg.placeholder.dtype is expected to be float32\00", align 1
# @.str.6 = private constant [157 x i8] c"Assert fail: (3 == int32(arg.placeholder.shape[0])), Argument arg.placeholder.shape[0] has an unsatisfied constraint: (3 == int32(arg.placeholder.shape[0]))\00", align 1
# @.str.7 = private constant [109 x i8] c"Assert fail: (1 == int32(arg.placeholder.strides[0])), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.8 = private constant [196 x i8] c"Assert fail: ((uint64)0 == tir.tvm_struct_get(arg.placeholder, 0, 8)), Argument arg.placeholder.byte_offset has an unsatisfied constraint: ((uint64)0 == tir.tvm_struct_get(arg.placeholder, 0, 8))\00", align 1
# @.str.9 = private constant [182 x i8] c"Assert fail: (1 == tir.tvm_struct_get(arg.placeholder, 0, 10)), Argument arg.placeholder.device_type has an unsatisfied constraint: (1 == tir.tvm_struct_get(arg.placeholder, 0, 10))\00", align 1
# @.str.10 = private constant [107 x i8] c"Assert fail: (0 == tir.tvm_struct_get(arg.placeholder, 0, 4)), arg.placeholder.ndim is expected to equal 0\00", align 1
# @.str.11 = private constant [188 x i8] c"Assert fail: (dev_id == tir.tvm_struct_get(arg.placeholder, 0, 9)), Argument arg.placeholder.device_id has an unsatisfied constraint: (dev_id == tir.tvm_struct_get(arg.placeholder, 0, 9))\00", align 1
# @.str.12 = private constant [95 x i8] c"Assert fail: (1 == tir.tvm_struct_get(arg.T_add, 0, 4)), arg.T_add.ndim is expected to equal 1\00", align 1
# @.str.13 = private constant [218 x i8] c"Assert fail: (((tir.tvm_struct_get(arg.T_add, 0, 5) == (uint8)2) && (tir.tvm_struct_get(arg.T_add, 0, 6) == (uint8)32)) && (tir.tvm_struct_get(arg.T_add, 0, 7) == (uint16)1)), arg.T_add.dtype is expected to be float32\00", align 1
# @.str.14 = private constant [139 x i8] c"Assert fail: (3 == int32(arg.T_add.shape[0])), Argument arg.T_add.shape[0] has an unsatisfied constraint: (3 == int32(arg.T_add.shape[0]))\00", align 1
# @.str.15 = private constant [97 x i8] c"Assert fail: (1 == int32(arg.T_add.strides[0])), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.16 = private constant [178 x i8] c"Assert fail: ((uint64)0 == tir.tvm_struct_get(arg.T_add, 0, 8)), Argument arg.T_add.byte_offset has an unsatisfied constraint: ((uint64)0 == tir.tvm_struct_get(arg.T_add, 0, 8))\00", align 1
# @.str.17 = private constant [164 x i8] c"Assert fail: (1 == tir.tvm_struct_get(arg.T_add, 0, 10)), Argument arg.T_add.device_type has an unsatisfied constraint: (1 == tir.tvm_struct_get(arg.T_add, 0, 10))\00", align 1
# @.str.18 = private constant [170 x i8] c"Assert fail: (dev_id == tir.tvm_struct_get(arg.T_add, 0, 9)), Argument arg.T_add.device_id has an unsatisfied constraint: (dev_id == tir.tvm_struct_get(arg.T_add, 0, 9))\00", align 1
# @.str.19 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_1: num_args should be 3\00", align 1
# @.str.20 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_1: Expect arg[0] to be pointer\00", align 1
# @.str.21 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_1: Expect arg[1] to be pointer\00", align 1
# @.str.22 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_1: Expect arg[2] to be pointer\00", align 1
# @.str.23 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_10: num_args should be 3\00", align 1
# @.str.24 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_10: Expect arg[0] to be pointer\00", align 1
# @.str.25 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_10: Expect arg[1] to be pointer\00", align 1
# @.str.26 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_10: Expect arg[2] to be pointer\00", align 1
# @.str.27 = private constant [107 x i8] c"Assert fail: (4 == tir.tvm_struct_get(arg.placeholder, 0, 4)), arg.placeholder.ndim is expected to equal 4\00", align 1
# @.str.28 = private constant [157 x i8] c"Assert fail: (1 == int32(arg.placeholder.shape[0])), Argument arg.placeholder.shape[0] has an unsatisfied constraint: (1 == int32(arg.placeholder.shape[0]))\00", align 1
# @.str.29 = private constant [161 x i8] c"Assert fail: (128 == int32(arg.placeholder.shape[1])), Argument arg.placeholder.shape[1] has an unsatisfied constraint: (128 == int32(arg.placeholder.shape[1]))\00", align 1
# @.str.30 = private constant [159 x i8] c"Assert fail: (28 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (28 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.31 = private constant [159 x i8] c"Assert fail: (28 == int32(arg.placeholder.shape[3])), Argument arg.placeholder.shape[3] has an unsatisfied constraint: (28 == int32(arg.placeholder.shape[3]))\00", align 1
# @.str.32 = private constant [255 x i8] c"Assert fail: ((((1 == int32(arg.placeholder.strides[3])) && (28 == int32(arg.placeholder.strides[2]))) && (784 == int32(arg.placeholder.strides[1]))) && (100352 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.33 = private constant [107 x i8] c"Assert fail: (3 == tir.tvm_struct_get(arg.placeholder, 0, 4)), arg.placeholder.ndim is expected to equal 3\00", align 1
# @.str.34 = private constant [161 x i8] c"Assert fail: (128 == int32(arg.placeholder.shape[0])), Argument arg.placeholder.shape[0] has an unsatisfied constraint: (128 == int32(arg.placeholder.shape[0]))\00", align 1
# @.str.35 = private constant [157 x i8] c"Assert fail: (1 == int32(arg.placeholder.shape[1])), Argument arg.placeholder.shape[1] has an unsatisfied constraint: (1 == int32(arg.placeholder.shape[1]))\00", align 1
# @.str.36 = private constant [157 x i8] c"Assert fail: (1 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (1 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.37 = private constant [201 x i8] c"Assert fail: (((1 == int32(arg.placeholder.strides[2])) && (1 == int32(arg.placeholder.strides[1]))) && (1 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.38 = private constant [95 x i8] c"Assert fail: (4 == tir.tvm_struct_get(arg.T_add, 0, 4)), arg.T_add.ndim is expected to equal 4\00", align 1
# @.str.39 = private constant [139 x i8] c"Assert fail: (1 == int32(arg.T_add.shape[0])), Argument arg.T_add.shape[0] has an unsatisfied constraint: (1 == int32(arg.T_add.shape[0]))\00", align 1
# @.str.40 = private constant [143 x i8] c"Assert fail: (128 == int32(arg.T_add.shape[1])), Argument arg.T_add.shape[1] has an unsatisfied constraint: (128 == int32(arg.T_add.shape[1]))\00", align 1
# @.str.41 = private constant [141 x i8] c"Assert fail: (28 == int32(arg.T_add.shape[2])), Argument arg.T_add.shape[2] has an unsatisfied constraint: (28 == int32(arg.T_add.shape[2]))\00", align 1
# @.str.42 = private constant [141 x i8] c"Assert fail: (28 == int32(arg.T_add.shape[3])), Argument arg.T_add.shape[3] has an unsatisfied constraint: (28 == int32(arg.T_add.shape[3]))\00", align 1
# @.str.43 = private constant [225 x i8] c"Assert fail: ((((1 == int32(arg.T_add.strides[3])) && (28 == int32(arg.T_add.strides[2]))) && (784 == int32(arg.T_add.strides[1]))) && (100352 == int32(arg.T_add.strides[0]))), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.44 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_11: num_args should be 3\00", align 1
# @.str.45 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_11: Expect arg[0] to be pointer\00", align 1
# @.str.46 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_11: Expect arg[1] to be pointer\00", align 1
# @.str.47 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_11: Expect arg[2] to be pointer\00", align 1
# @.str.49 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_12: num_args should be 3\00", align 1
# @.str.50 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_12: Expect arg[0] to be pointer\00", align 1
# @.str.51 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_12: Expect arg[1] to be pointer\00", align 1
# @.str.52 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_12: Expect arg[2] to be pointer\00", align 1
# @.str.53 = private constant [161 x i8] c"Assert fail: (256 == int32(arg.placeholder.shape[0])), Argument arg.placeholder.shape[0] has an unsatisfied constraint: (256 == int32(arg.placeholder.shape[0]))\00", align 1
# @.str.54 = private constant [143 x i8] c"Assert fail: (256 == int32(arg.T_add.shape[0])), Argument arg.T_add.shape[0] has an unsatisfied constraint: (256 == int32(arg.T_add.shape[0]))\00", align 1
# @.str.56 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_13: num_args should be 3\00", align 1
# @.str.57 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_13: Expect arg[0] to be pointer\00", align 1
# @.str.58 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_13: Expect arg[1] to be pointer\00", align 1
# @.str.59 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_13: Expect arg[2] to be pointer\00", align 1
# @.str.61 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_14: num_args should be 3\00", align 1
# @.str.62 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_14: Expect arg[0] to be pointer\00", align 1
# @.str.63 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_14: Expect arg[1] to be pointer\00", align 1
# @.str.64 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_14: Expect arg[2] to be pointer\00", align 1
# @.str.65 = private constant [161 x i8] c"Assert fail: (256 == int32(arg.placeholder.shape[1])), Argument arg.placeholder.shape[1] has an unsatisfied constraint: (256 == int32(arg.placeholder.shape[1]))\00", align 1
# @.str.66 = private constant [159 x i8] c"Assert fail: (14 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (14 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.67 = private constant [159 x i8] c"Assert fail: (14 == int32(arg.placeholder.shape[3])), Argument arg.placeholder.shape[3] has an unsatisfied constraint: (14 == int32(arg.placeholder.shape[3]))\00", align 1
# @.str.68 = private constant [254 x i8] c"Assert fail: ((((1 == int32(arg.placeholder.strides[3])) && (14 == int32(arg.placeholder.strides[2]))) && (196 == int32(arg.placeholder.strides[1]))) && (50176 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.69 = private constant [143 x i8] c"Assert fail: (256 == int32(arg.T_add.shape[1])), Argument arg.T_add.shape[1] has an unsatisfied constraint: (256 == int32(arg.T_add.shape[1]))\00", align 1
# @.str.70 = private constant [141 x i8] c"Assert fail: (14 == int32(arg.T_add.shape[2])), Argument arg.T_add.shape[2] has an unsatisfied constraint: (14 == int32(arg.T_add.shape[2]))\00", align 1
# @.str.71 = private constant [141 x i8] c"Assert fail: (14 == int32(arg.T_add.shape[3])), Argument arg.T_add.shape[3] has an unsatisfied constraint: (14 == int32(arg.T_add.shape[3]))\00", align 1
# @.str.72 = private constant [224 x i8] c"Assert fail: ((((1 == int32(arg.T_add.strides[3])) && (14 == int32(arg.T_add.strides[2]))) && (196 == int32(arg.T_add.strides[1]))) && (50176 == int32(arg.T_add.strides[0]))), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.74 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_15: num_args should be 3\00", align 1
# @.str.75 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_15: Expect arg[0] to be pointer\00", align 1
# @.str.76 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_15: Expect arg[1] to be pointer\00", align 1
# @.str.77 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_15: Expect arg[2] to be pointer\00", align 1
# @.str.79 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_16: num_args should be 3\00", align 1
# @.str.80 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_16: Expect arg[0] to be pointer\00", align 1
# @.str.81 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_16: Expect arg[1] to be pointer\00", align 1
# @.str.82 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_16: Expect arg[2] to be pointer\00", align 1
# @.str.83 = private constant [161 x i8] c"Assert fail: (512 == int32(arg.placeholder.shape[0])), Argument arg.placeholder.shape[0] has an unsatisfied constraint: (512 == int32(arg.placeholder.shape[0]))\00", align 1
# @.str.84 = private constant [143 x i8] c"Assert fail: (512 == int32(arg.T_add.shape[0])), Argument arg.T_add.shape[0] has an unsatisfied constraint: (512 == int32(arg.T_add.shape[0]))\00", align 1
# @.str.86 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_17: num_args should be 3\00", align 1
# @.str.87 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_17: Expect arg[0] to be pointer\00", align 1
# @.str.88 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_17: Expect arg[1] to be pointer\00", align 1
# @.str.89 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_17: Expect arg[2] to be pointer\00", align 1
# @.str.91 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_18: num_args should be 3\00", align 1
# @.str.92 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_18: Expect arg[0] to be pointer\00", align 1
# @.str.93 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_18: Expect arg[1] to be pointer\00", align 1
# @.str.94 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_18: Expect arg[2] to be pointer\00", align 1
# @.str.95 = private constant [161 x i8] c"Assert fail: (512 == int32(arg.placeholder.shape[1])), Argument arg.placeholder.shape[1] has an unsatisfied constraint: (512 == int32(arg.placeholder.shape[1]))\00", align 1
# @.str.96 = private constant [157 x i8] c"Assert fail: (7 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (7 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.97 = private constant [157 x i8] c"Assert fail: (7 == int32(arg.placeholder.shape[3])), Argument arg.placeholder.shape[3] has an unsatisfied constraint: (7 == int32(arg.placeholder.shape[3]))\00", align 1
# @.str.98 = private constant [252 x i8] c"Assert fail: ((((1 == int32(arg.placeholder.strides[3])) && (7 == int32(arg.placeholder.strides[2]))) && (49 == int32(arg.placeholder.strides[1]))) && (25088 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.99 = private constant [143 x i8] c"Assert fail: (512 == int32(arg.T_add.shape[1])), Argument arg.T_add.shape[1] has an unsatisfied constraint: (512 == int32(arg.T_add.shape[1]))\00", align 1
# @.str.100 = private constant [139 x i8] c"Assert fail: (7 == int32(arg.T_add.shape[2])), Argument arg.T_add.shape[2] has an unsatisfied constraint: (7 == int32(arg.T_add.shape[2]))\00", align 1
# @.str.101 = private constant [139 x i8] c"Assert fail: (7 == int32(arg.T_add.shape[3])), Argument arg.T_add.shape[3] has an unsatisfied constraint: (7 == int32(arg.T_add.shape[3]))\00", align 1
# @.str.102 = private constant [222 x i8] c"Assert fail: ((((1 == int32(arg.T_add.strides[3])) && (7 == int32(arg.T_add.strides[2]))) && (49 == int32(arg.T_add.strides[1]))) && (25088 == int32(arg.T_add.strides[0]))), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.104 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_19: num_args should be 3\00", align 1
# @.str.105 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_19: Expect arg[0] to be pointer\00", align 1
# @.str.106 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_19: Expect arg[1] to be pointer\00", align 1
# @.str.107 = private constant [175 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_19: Expect arg[2] to be pointer\00", align 1
# @.str.109 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_2: num_args should be 3\00", align 1
# @.str.110 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_2: Expect arg[0] to be pointer\00", align 1
# @.str.111 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_2: Expect arg[1] to be pointer\00", align 1
# @.str.112 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_2: Expect arg[2] to be pointer\00", align 1
# @.str.113 = private constant [157 x i8] c"Assert fail: (3 == int32(arg.placeholder.shape[1])), Argument arg.placeholder.shape[1] has an unsatisfied constraint: (3 == int32(arg.placeholder.shape[1]))\00", align 1
# @.str.114 = private constant [161 x i8] c"Assert fail: (224 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (224 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.115 = private constant [161 x i8] c"Assert fail: (224 == int32(arg.placeholder.shape[3])), Argument arg.placeholder.shape[3] has an unsatisfied constraint: (224 == int32(arg.placeholder.shape[3]))\00", align 1
# @.str.116 = private constant [258 x i8] c"Assert fail: ((((1 == int32(arg.placeholder.strides[3])) && (224 == int32(arg.placeholder.strides[2]))) && (50176 == int32(arg.placeholder.strides[1]))) && (150528 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.117 = private constant [139 x i8] c"Assert fail: (3 == int32(arg.T_add.shape[1])), Argument arg.T_add.shape[1] has an unsatisfied constraint: (3 == int32(arg.T_add.shape[1]))\00", align 1
# @.str.118 = private constant [143 x i8] c"Assert fail: (224 == int32(arg.T_add.shape[2])), Argument arg.T_add.shape[2] has an unsatisfied constraint: (224 == int32(arg.T_add.shape[2]))\00", align 1
# @.str.119 = private constant [143 x i8] c"Assert fail: (224 == int32(arg.T_add.shape[3])), Argument arg.T_add.shape[3] has an unsatisfied constraint: (224 == int32(arg.T_add.shape[3]))\00", align 1
# @.str.120 = private constant [228 x i8] c"Assert fail: ((((1 == int32(arg.T_add.strides[3])) && (224 == int32(arg.T_add.strides[2]))) && (50176 == int32(arg.T_add.strides[1]))) && (150528 == int32(arg.T_add.strides[0]))), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.122 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_3: num_args should be 3\00", align 1
# @.str.123 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_3: Expect arg[0] to be pointer\00", align 1
# @.str.124 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_3: Expect arg[1] to be pointer\00", align 1
# @.str.125 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_3: Expect arg[2] to be pointer\00", align 1
# @.str.126 = private constant [159 x i8] c"Assert fail: (64 == int32(arg.placeholder.shape[0])), Argument arg.placeholder.shape[0] has an unsatisfied constraint: (64 == int32(arg.placeholder.shape[0]))\00", align 1
# @.str.127 = private constant [141 x i8] c"Assert fail: (64 == int32(arg.T_add.shape[0])), Argument arg.T_add.shape[0] has an unsatisfied constraint: (64 == int32(arg.T_add.shape[0]))\00", align 1
# @.str.129 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_4: num_args should be 3\00", align 1
# @.str.130 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_4: Expect arg[0] to be pointer\00", align 1
# @.str.131 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_4: Expect arg[1] to be pointer\00", align 1
# @.str.132 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_4: Expect arg[2] to be pointer\00", align 1
# @.str.134 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_5: num_args should be 3\00", align 1
# @.str.135 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_5: Expect arg[0] to be pointer\00", align 1
# @.str.136 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_5: Expect arg[1] to be pointer\00", align 1
# @.str.137 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_5: Expect arg[2] to be pointer\00", align 1
# @.str.138 = private constant [159 x i8] c"Assert fail: (64 == int32(arg.placeholder.shape[1])), Argument arg.placeholder.shape[1] has an unsatisfied constraint: (64 == int32(arg.placeholder.shape[1]))\00", align 1
# @.str.139 = private constant [161 x i8] c"Assert fail: (112 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (112 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.140 = private constant [161 x i8] c"Assert fail: (112 == int32(arg.placeholder.shape[3])), Argument arg.placeholder.shape[3] has an unsatisfied constraint: (112 == int32(arg.placeholder.shape[3]))\00", align 1
# @.str.141 = private constant [258 x i8] c"Assert fail: ((((1 == int32(arg.placeholder.strides[3])) && (112 == int32(arg.placeholder.strides[2]))) && (12544 == int32(arg.placeholder.strides[1]))) && (802816 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.142 = private constant [141 x i8] c"Assert fail: (64 == int32(arg.T_add.shape[1])), Argument arg.T_add.shape[1] has an unsatisfied constraint: (64 == int32(arg.T_add.shape[1]))\00", align 1
# @.str.143 = private constant [143 x i8] c"Assert fail: (112 == int32(arg.T_add.shape[2])), Argument arg.T_add.shape[2] has an unsatisfied constraint: (112 == int32(arg.T_add.shape[2]))\00", align 1
# @.str.144 = private constant [143 x i8] c"Assert fail: (112 == int32(arg.T_add.shape[3])), Argument arg.T_add.shape[3] has an unsatisfied constraint: (112 == int32(arg.T_add.shape[3]))\00", align 1
# @.str.145 = private constant [228 x i8] c"Assert fail: ((((1 == int32(arg.T_add.strides[3])) && (112 == int32(arg.T_add.strides[2]))) && (12544 == int32(arg.T_add.strides[1]))) && (802816 == int32(arg.T_add.strides[0]))), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.147 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_6: num_args should be 3\00", align 1
# @.str.148 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_6: Expect arg[0] to be pointer\00", align 1
# @.str.149 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_6: Expect arg[1] to be pointer\00", align 1
# @.str.150 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_6: Expect arg[2] to be pointer\00", align 1
# @.str.151 = private constant [159 x i8] c"Assert fail: (56 == int32(arg.placeholder.shape[2])), Argument arg.placeholder.shape[2] has an unsatisfied constraint: (56 == int32(arg.placeholder.shape[2]))\00", align 1
# @.str.152 = private constant [159 x i8] c"Assert fail: (56 == int32(arg.placeholder.shape[3])), Argument arg.placeholder.shape[3] has an unsatisfied constraint: (56 == int32(arg.placeholder.shape[3]))\00", align 1
# @.str.153 = private constant [256 x i8] c"Assert fail: ((((1 == int32(arg.placeholder.strides[3])) && (56 == int32(arg.placeholder.strides[2]))) && (3136 == int32(arg.placeholder.strides[1]))) && (200704 == int32(arg.placeholder.strides[0]))), arg.placeholder.strides: expected to be compact array\00", align 1
# @.str.154 = private constant [141 x i8] c"Assert fail: (56 == int32(arg.T_add.shape[2])), Argument arg.T_add.shape[2] has an unsatisfied constraint: (56 == int32(arg.T_add.shape[2]))\00", align 1
# @.str.155 = private constant [141 x i8] c"Assert fail: (56 == int32(arg.T_add.shape[3])), Argument arg.T_add.shape[3] has an unsatisfied constraint: (56 == int32(arg.T_add.shape[3]))\00", align 1
# @.str.156 = private constant [226 x i8] c"Assert fail: ((((1 == int32(arg.T_add.strides[3])) && (56 == int32(arg.T_add.strides[2]))) && (3136 == int32(arg.T_add.strides[1]))) && (200704 == int32(arg.T_add.strides[0]))), arg.T_add.strides: expected to be compact array\00", align 1
# @.str.158 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_7: num_args should be 3\00", align 1
# @.str.159 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_7: Expect arg[0] to be pointer\00", align 1
# @.str.160 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_7: Expect arg[1] to be pointer\00", align 1
# @.str.161 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_7: Expect arg[2] to be pointer\00", align 1
# @.str.163 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_8: num_args should be 3\00", align 1
# @.str.164 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_8: Expect arg[0] to be pointer\00", align 1
# @.str.165 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_8: Expect arg[1] to be pointer\00", align 1
# @.str.166 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_8: Expect arg[2] to be pointer\00", align 1
# @.str.167 = private constant [143 x i8] c"Assert fail: (128 == int32(arg.T_add.shape[0])), Argument arg.T_add.shape[0] has an unsatisfied constraint: (128 == int32(arg.T_add.shape[0]))\00", align 1
# @.str.169 = private constant [79 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_add_9: num_args should be 3\00", align 1
# @.str.170 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_9: Expect arg[0] to be pointer\00", align 1
# @.str.171 = private constant [198 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_add_9: Expect arg[1] to be pointer\00", align 1
# @.str.172 = private constant [174 x i8] c"Assert fail: ((((arg.T_add.code == 3) || (arg.T_add.code == 13)) || (arg.T_add.code == 7)) || (arg.T_add.code == 4)), tvmgen_default_fused_add_9: Expect arg[2] to be pointer\00", align 1
# @.str.174 = private constant [80 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_divide: num_args should be 3\00", align 1
# @.str.175 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide: Expect arg[0] to be pointer\00", align 1
# @.str.176 = private constant [199 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide: Expect arg[1] to be pointer\00", align 1
# @.str.177 = private constant [187 x i8] c"Assert fail: ((((arg.T_divide.code == 3) || (arg.T_divide.code == 13)) || (arg.T_divide.code == 7)) || (arg.T_divide.code == 4)), tvmgen_default_fused_divide: Expect arg[2] to be pointer\00", align 1
# @.str.178 = private constant [101 x i8] c"Assert fail: (1 == tir.tvm_struct_get(arg.T_divide, 0, 4)), arg.T_divide.ndim is expected to equal 1\00", align 1
# @.str.179 = private constant [230 x i8] c"Assert fail: (((tir.tvm_struct_get(arg.T_divide, 0, 5) == (uint8)2) && (tir.tvm_struct_get(arg.T_divide, 0, 6) == (uint8)32)) && (tir.tvm_struct_get(arg.T_divide, 0, 7) == (uint16)1)), arg.T_divide.dtype is expected to be float32\00", align 1
# @.str.180 = private constant [148 x i8] c"Assert fail: (3 == int32(arg.T_divide.shape[0])), Argument arg.T_divide.shape[0] has an unsatisfied constraint: (3 == int32(arg.T_divide.shape[0]))\00", align 1
# @.str.181 = private constant [103 x i8] c"Assert fail: (1 == int32(arg.T_divide.strides[0])), arg.T_divide.strides: expected to be compact array\00", align 1
# @.str.182 = private constant [187 x i8] c"Assert fail: ((uint64)0 == tir.tvm_struct_get(arg.T_divide, 0, 8)), Argument arg.T_divide.byte_offset has an unsatisfied constraint: ((uint64)0 == tir.tvm_struct_get(arg.T_divide, 0, 8))\00", align 1
# @.str.183 = private constant [173 x i8] c"Assert fail: (1 == tir.tvm_struct_get(arg.T_divide, 0, 10)), Argument arg.T_divide.device_type has an unsatisfied constraint: (1 == tir.tvm_struct_get(arg.T_divide, 0, 10))\00", align 1
# @.str.184 = private constant [179 x i8] c"Assert fail: (dev_id == tir.tvm_struct_get(arg.T_divide, 0, 9)), Argument arg.T_divide.device_id has an unsatisfied constraint: (dev_id == tir.tvm_struct_get(arg.T_divide, 0, 9))\00", align 1
# @.str.185 = private constant [82 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_divide_1: num_args should be 3\00", align 1
# @.str.186 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_1: Expect arg[0] to be pointer\00", align 1
# @.str.187 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_1: Expect arg[1] to be pointer\00", align 1
# @.str.188 = private constant [189 x i8] c"Assert fail: ((((arg.T_divide.code == 3) || (arg.T_divide.code == 13)) || (arg.T_divide.code == 7)) || (arg.T_divide.code == 4)), tvmgen_default_fused_divide_1: Expect arg[2] to be pointer\00", align 1
# @.str.189 = private constant [150 x i8] c"Assert fail: (64 == int32(arg.T_divide.shape[0])), Argument arg.T_divide.shape[0] has an unsatisfied constraint: (64 == int32(arg.T_divide.shape[0]))\00", align 1
# @.str.191 = private constant [82 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_divide_2: num_args should be 3\00", align 1
# @.str.192 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_2: Expect arg[0] to be pointer\00", align 1
# @.str.193 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_2: Expect arg[1] to be pointer\00", align 1
# @.str.194 = private constant [189 x i8] c"Assert fail: ((((arg.T_divide.code == 3) || (arg.T_divide.code == 13)) || (arg.T_divide.code == 7)) || (arg.T_divide.code == 4)), tvmgen_default_fused_divide_2: Expect arg[2] to be pointer\00", align 1
# @.str.195 = private constant [152 x i8] c"Assert fail: (128 == int32(arg.T_divide.shape[0])), Argument arg.T_divide.shape[0] has an unsatisfied constraint: (128 == int32(arg.T_divide.shape[0]))\00", align 1
# @.str.197 = private constant [82 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_divide_3: num_args should be 3\00", align 1
# @.str.198 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_3: Expect arg[0] to be pointer\00", align 1
# @.str.199 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_3: Expect arg[1] to be pointer\00", align 1
# @.str.200 = private constant [189 x i8] c"Assert fail: ((((arg.T_divide.code == 3) || (arg.T_divide.code == 13)) || (arg.T_divide.code == 7)) || (arg.T_divide.code == 4)), tvmgen_default_fused_divide_3: Expect arg[2] to be pointer\00", align 1
# @.str.201 = private constant [152 x i8] c"Assert fail: (256 == int32(arg.T_divide.shape[0])), Argument arg.T_divide.shape[0] has an unsatisfied constraint: (256 == int32(arg.T_divide.shape[0]))\00", align 1
# @.str.203 = private constant [82 x i8] c"Assert fail: (num_args == 3), tvmgen_default_fused_divide_4: num_args should be 3\00", align 1
# @.str.204 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_4: Expect arg[0] to be pointer\00", align 1
# @.str.205 = private constant [201 x i8] c"Assert fail: ((((arg.placeholder.code == 3) || (arg.placeholder.code == 13)) || (arg.placeholder.code == 7)) || (arg.placeholder.code == 4)), tvmgen_default_fused_divide_4: Expect arg[1] to be pointer\00", align 1
# @.str.206 = private constant [189 x i8] c"Assert fail: ((((arg.T_divide.code == 3) || (arg.T_divide.code == 13)) || (arg.T_divide.code == 7)) || (arg.T_divide.code == 4)), tvmgen_default_fused_divide_4: Expect arg[2] to be pointer\00", align 1
# @.str.207 = private constant [152 x i8] c"Assert fail: (512 == int32(arg.T_divide.shape[0])), Argument arg.T_divide.shape[0] has an unsatisfied constraint: (512 == int32(arg.T_divide.shape[0]))\00", align 1
# @.str.209 = private constant [85 x i8] c"Assert fail: (num_args == 2), tvmgen_default_fused_expand_dims: num_args should be 2\00", align 1
# ...
# !6794 = !{!"0x4ad9530.w1024.b0", !6795, i64 0}
# !6795 = !{!"0x4ad9530", !7, i64 0}
# !6796 = !{!6797, !6797, i64 0}
# !6797 = !{!"0x4ad9530.w8.b8", !6788, i64 0}
# !6798 = !{!6799, !6799, i64 0}
# !6799 = !{!"0x4ad9530.w8.b16", !6800, i64 0}
# !6800 = !{!"0x4ad9530.w16.b16", !6789, i64 0}
# !6801 = !{!6802, !6802, i64 0}
# !6802 = !{!"0x4ad9530.w8.b24", !6800, i64 0}
# !6803 = !{!6804, !6804, i64 0}
# !6804 = !{!"0x4517100", !7, i64 0}
# !6805 = !{!6806, !6806, i64 0}
# !6806 = !{!"0x44b5460", !7, i64 0}
# !6807 = !{!6808, !6808, i64 0}
# !6808 = !{!"0x4aa30d0.w4.b0", !6809, i64 0}
# !6809 = !{!"0x4aa30d0.w8.b0", !6810, i64 0}
# !6810 = !{!"0x4aa30d0.w16.b0", !6811, i64 0}
# !6811 = !{!"0x4aa30d0.w32.b0", !6812, i64 0}
# !6812 = !{!"0x4aa30d0.w64.b0", !6813, i64 0}
# !6813 = !{!"0x4aa30d0.w128.b0", !6814, i64 0}
# !6814 = !{!"0x4aa30d0.w256.b0", !6815, i64 0}
# !6815 = !{!"0x4aa30d0.w512.b0", !6816, i64 0}
# !6816 = !{!"0x4aa30d0.w1024.b0", !6817, i64 0}
# !6817 = !{!"0x4aa30d0", !7, i64 0}
# !6818 = !{!6819, !6819, i64 0}
# !6819 = !{!"0x4aa30d0.w4.b4", !6809, i64 0}
# !6820 = !{!6821, !6821, i64 0}
# !6821 = !{!"0x4aa6ad0.w8.b0", !6822, i64 0}
# !6822 = !{!"0x4aa6ad0.w16.b0", !6823, i64 0}
# !6823 = !{!"0x4aa6ad0.w32.b0", !6824, i64 0}
# !6824 = !{!"0x4aa6ad0.w64.b0", !6825, i64 0}
# !6825 = !{!"0x4aa6ad0.w128.b0", !6826, i64 0}
# !6826 = !{!"0x4aa6ad0.w256.b0", !6827, i64 0}
# !6827 = !{!"0x4aa6ad0.w512.b0", !6828, i64 0}
# !6828 = !{!"0x4aa6ad0.w1024.b0", !6829, i64 0}
# !6829 = !{!"0x4aa6ad0", !7, i64 0}
# !6830 = !{!6831, !6831, i64 0}
# !6831 = !{!"0x4aa6ad0.w8.b8", !6822, i64 0}
# !6832 = !{!6833, !6833, i64 0}
# !6833 = !{!"0x4aa4aa0.w8.b0", !6834, i64 0}
# !6834 = !{!"0x4aa4aa0.w16.b0", !6835, i64 0}
# !6835 = !{!"0x4aa4aa0.w32.b0", !6836, i64 0}
# !6836 = !{!"0x4aa4aa0.w64.b0", !6837, i64 0}
# !6837 = !{!"0x4aa4aa0.w128.b0", !6838, i64 0}
# !6838 = !{!"0x4aa4aa0.w256.b0", !6839, i64 0}
# !6839 = !{!"0x4aa4aa0.w512.b0", !6840, i64 0}
# !6840 = !{!"0x4aa4aa0.w1024.b0", !6841, i64 0}
# !6841 = !{!"0x4aa4aa0", !7, i64 0}
# !6842 = !{!6843, !6843, i64 0}
# !6843 = !{!"0x4aa4aa0.w8.b8", !6834, i64 0}
# !6844 = !{!6845, !6845, i64 0}
# !6845 = !{!"0x4b41500.w8.b0", !6846, i64 0}
# !6846 = !{!"0x4b41500.w16.b0", !6847, i64 0}
# !6847 = !{!"0x4b41500.w32.b0", !6848, i64 0}
# !6848 = !{!"0x4b41500.w64.b0", !6849, i64 0}
# !6849 = !{!"0x4b41500.w128.b0", !6850, i64 0}
# !6850 = !{!"0x4b41500.w256.b0", !6851, i64 0}
# !6851 = !{!"0x4b41500.w512.b0", !6852, i64 0}
# !6852 = !{!"0x4b41500.w1024.b0", !6853, i64 0}
# !6853 = !{!"0x4b41500", !7, i64 0}
# !6854 = !{!6855, !6855, i64 0}
# !6855 = !{!"0x4b41500.w8.b8", !6846, i64 0}
# !6856 = !{!6857, !6857, i64 0}
# !6857 = !{!"0x4b41b00.w8.b0", !6858, i64 0}
# !6858 = !{!"0x4b41b00.w16.b0", !6859, i64 0}
# !6859 = !{!"0x4b41b00.w32.b0", !6860, i64 0}
# !6860 = !{!"0x4b41b00.w64.b0", !6861, i64 0}
# !6861 = !{!"0x4b41b00.w128.b0", !6862, i64 0}
# !6862 = !{!"0x4b41b00.w256.b0", !6863, i64 0}
# !6863 = !{!"0x4b41b00.w512.b0", !6864, i64 0}
# !6864 = !{!"0x4b41b00.w1024.b0", !6865, i64 0}
# !6865 = !{!"0x4b41b00", !7, i64 0}
# !6866 = !{!6867, !6867, i64 0}
# !6867 = !{!"0x4b41b00.w8.b8", !6858, i64 0}
# !6868 = !{!6869, !6869, i64 0}
# !6869 = !{!"0x459c0b0", !7, i64 0}
# !6870 = !{!6871, !6871, i64 0}
# !6871 = !{!"0x45984a0", !7, i64 0}
# !6872 = distinct !{!6872, !2463}
# !6873 = !{!6874, !6874, i64 0}
# !6874 = !{!"0x45997f0", !7, i64 0}
# !6875 = distinct !{!6875, !2463}
# !6876 = !{!6877, !6877, i64 0}
# !6877 = !{!"0x4ac9c50.w4.b0", !6878, i64 0}
# !6878 = !{!"0x4ac9c50.w8.b0", !6879, i64 0}
# !6879 = !{!"0x4ac9c50.w16.b0", !6880, i64 0}
# !6880 = !{!"0x4ac9c50.w32.b0", !6881, i64 0}
# !6881 = !{!"0x4ac9c50.w64.b0", !6882, i64 0}
# !6882 = !{!"0x4ac9c50.w128.b0", !6883, i64 0}
# !6883 = !{!"0x4ac9c50.w256.b0", !6884, i64 0}
# !6884 = !{!"0x4ac9c50.w512.b0", !6885, i64 0}
# !6885 = !{!"0x4ac9c50.w1024.b0", !6886, i64 0}
# !6886 = !{!"0x4ac9c50", !7, i64 0}
# !6887 = !{!6888, !6888, i64 0}
# !6888 = !{!"0x4ac9c50.w4.b4", !6878, i64 0}
# !6889 = !{!6890, !6890, i64 0}
# !6890 = !{!"0x4acc2c0.w8.b0", !6891, i64 0}
# !6891 = !{!"0x4acc2c0.w16.b0", !6892, i64 0}
# !6892 = !{!"0x4acc2c0.w32.b0", !6893, i64 0}
# !6893 = !{!"0x4acc2c0.w64.b0", !6894, i64 0}
# !6894 = !{!"0x4acc2c0.w128.b0", !6895, i64 0}
# !6895 = !{!"0x4acc2c0.w256.b0", !6896, i64 0}
# !6896 = !{!"0x4acc2c0.w512.b0", !6897, i64 0}
# !6897 = !{!"0x4acc2c0.w1024.b0", !6898, i64 0}
# !6898 = !{!"0x4acc2c0", !7, i64 0}
# !6899 = !{!6900, !6900, i64 0}
# !6900 = !{!"0x4acb620.w8.b0", !6901, i64 0}
# !6901 = !{!"0x4acb620.w16.b0", !6902, i64 0}
# !6902 = !{!"0x4acb620.w32.b0", !6903, i64 0}
# !6903 = !{!"0x4acb620.w64.b0", !6904, i64 0}
# !6904 = !{!"0x4acb620.w128.b0", !6905, i64 0}
# !6905 = !{!"0x4acb620.w256.b0", !6906, i64 0}
# !6906 = !{!"0x4acb620.w512.b0", !6907, i64 0}
# !6907 = !{!"0x4acb620.w1024.b0", !6908, i64 0}
# !6908 = !{!"0x4acb620", !7, i64 0}
# !6909 = !{!6910, !6910, i64 0}
# !6910 = !{!"0x4ad5d00.w8.b0", !6911, i64 0}
# !6911 = !{!"0x4ad5d00.w16.b0", !6912, i64 0}
# !6912 = !{!"0x4ad5d00.w32.b0", !6913, i64 0}
# !6913 = !{!"0x4ad5d00.w64.b0", !6914, i64 0}
# !6914 = !{!"0x4ad5d00.w128.b0", !6915, i64 0}
# !6915 = !{!"0x4ad5d00.w256.b0", !6916, i64 0}
# !6916 = !{!"0x4ad5d00.w512.b0", !6917, i64 0}
# !6917 = !{!"0x4ad5d00.w1024.b0", !6918, i64 0}
# !6918 = !{!"0x4ad5d00", !7, i64 0}
# !6919 = !{!6920, !6920, i64 0}
# !6920 = !{!"0x4ad61b0.w8.b0", !6921, i64 0}
# !6921 = !{!"0x4ad61b0.w16.b0", !6922, i64 0}
# !6922 = !{!"0x4ad61b0.w32.b0", !6923, i64 0}
# !6923 = !{!"0x4ad61b0.w64.b0", !6924, i64 0}
# !6924 = !{!"0x4ad61b0.w128.b0", !6925, i64 0}
# !6925 = !{!"0x4ad61b0.w256.b0", !6926, i64 0}
# !6926 = !{!"0x4ad61b0.w512.b0", !6927, i64 0}
# !6927 = !{!"0x4ad61b0.w1024.b0", !6928, i64 0}
# !6928 = !{!"0x4ad61b0", !7, i64 0}
# !6929 = !{!6930, !6930, i64 0}
# !6930 = !{!"0x3683170.w16.b0", !6931, i64 0}
# !6931 = !{!"0x3683170.w32.b0", !6932, i64 0}
# !6932 = !{!"0x3683170.w64.b0", !6933, i64 0}
# !6933 = !{!"0x3683170.w128.b0", !6934, i64 0}
# !6934 = !{!"0x3683170.w256.b0", !6935, i64 0}
# !6935 = !{!"0x3683170.w512.b0", !6936, i64 0}
# !6936 = !{!"0x3683170.w1024.b0", !6937, i64 0}
# !6937 = !{!"0x3683170", !7, i64 0}
# !6938 = !{!6939, !6939, i64 0}
# !6939 = !{!"0x3932310.w16.b0", !6940, i64 0}
# !6940 = !{!"0x3932310.w32.b0", !6941, i64 0}
# !6941 = !{!"0x3932310.w64.b0", !6942, i64 0}
# !6942 = !{!"0x3932310.w128.b0", !6943, i64 0}
# !6943 = !{!"0x3932310.w256.b0", !6944, i64 0}
# !6944 = !{!"0x3932310.w512.b0", !6945, i64 0}
# !6945 = !{!"0x3932310.w1024.b0", !6946, i64 0}
# !6946 = !{!"0x3932310", !7, i64 0}
# !6947 = !{!6948, !6948, i64 0}
# !6948 = !{!"0x4b097c0.w4.b0", !6949, i64 0}
# !6949 = !{!"0x4b097c0.w8.b0", !6950, i64 0}
# !6950 = !{!"0x4b097c0.w16.b0", !6951, i64 0}
# !6951 = !{!"0x4b097c0.w32.b0", !6952, i64 0}
# !6952 = !{!"0x4b097c0.w64.b0", !6953, i64 0}
# !6953 = !{!"0x4b097c0.w128.b0", !6954, i64 0}
# !6954 = !{!"0x4b097c0.w256.b0", !6955, i64 0}
# !6955 = !{!"0x4b097c0.w512.b0", !6956, i64 0}
# !6956 = !{!"0x4b097c0.w1024.b0", !6957, i64 0}
# !6957 = !{!"0x4b097c0", !7, i64 0}
# !6958 = !{!6959, !6959, i64 0}
# !6959 = !{!"0x4b097c0.w4.b4", !6949, i64 0}
# !6960 = !{!6961, !6961, i64 0}
# !6961 = !{!"0x4b0dde0.w8.b0", !6962, i64 0}
# !6962 = !{!"0x4b0dde0.w16.b0", !6963, i64 0}
# !6963 = !{!"0x4b0dde0.w32.b0", !6964, i64 0}
# !6964 = !{!"0x4b0dde0.w64.b0", !6965, i64 0}
# !6965 = !{!"0x4b0dde0.w128.b0", !6966, i64 0}
# !6966 = !{!"0x4b0dde0.w256.b0", !6967, i64 0}
# !6967 = !{!"0x4b0dde0.w512.b0", !6968, i64 0}
# !6968 = !{!"0x4b0dde0.w1024.b0", !6969, i64 0}
# !6969 = !{!"0x4b0dde0", !7, i64 0}
# !6970 = !{!6971, !6971, i64 0}
# !6971 = !{!"0x4b0e280.w8.b0", !6972, i64 0}
# !6972 = !{!"0x4b0e280.w16.b0", !6973, i64 0}
# !6973 = !{!"0x4b0e280.w32.b0", !6974, i64 0}
# !6974 = !{!"0x4b0e280.w64.b0", !6975, i64 0}
# !6975 = !{!"0x4b0e280.w128.b0", !6976, i64 0}
# !6976 = !{!"0x4b0e280.w256.b0", !6977, i64 0}
# !6977 = !{!"0x4b0e280.w512.b0", !6978, i64 0}
# !6978 = !{!"0x4b0e280.w1024.b0", !6979, i64 0}
# !6979 = !{!"0x4b0e280", !7, i64 0}
# !6980 = !{!6981, !6981, i64 0}
# !6981 = !{!"0x43b6950.w8.b0", !6982, i64 0}
# !6982 = !{!"0x43b6950.w16.b0", !6983, i64 0}
# !6983 = !{!"0x43b6950.w32.b0", !6984, i64 0}
# !6984 = !{!"0x43b6950.w64.b0", !6985, i64 0}
# !6985 = !{!"0x43b6950.w128.b0", !6986, i64 0}
# !6986 = !{!"0x43b6950.w256.b0", !6987, i64 0}
# !6987 = !{!"0x43b6950.w512.b0", !6988, i64 0}
# !6988 = !{!"0x43b6950.w1024.b0", !6989, i64 0}
# !6989 = !{!"0x43b6950", !7, i64 0}
# !6990 = !{!6991, !6991, i64 0}
# !6991 = !{!"0x43b6e00.w8.b0", !6992, i64 0}
# !6992 = !{!"0x43b6e00.w16.b0", !6993, i64 0}
# !6993 = !{!"0x43b6e00.w32.b0", !6994, i64 0}
# !6994 = !{!"0x43b6e00.w64.b0", !6995, i64 0}
# !6995 = !{!"0x43b6e00.w128.b0", !6996, i64 0}
# !6996 = !{!"0x43b6e00.w256.b0", !6997, i64 0}
# !6997 = !{!"0x43b6e00.w512.b0", !6998, i64 0}
# !6998 = !{!"0x43b6e00.w1024.b0", !6999, i64 0}
# !6999 = !{!"0x43b6e00", !7, i64 0}
# !7000 = !{!7001, !7001, i64 0}
# !7001 = !{!"0x36e7560", !7, i64 0}
# !7002 = !{!7003, !7003, i64 0}
# !7003 = !{!"0x36e2220", !7, i64 0}
# !7004 = !{!7005, !7005, i64 0}
# !7005 = !{!"0x3969150.w4.b0", !7006, i64 0}
# !7006 = !{!"0x3969150.w8.b0", !7007, i64 0}
# !7007 = !{!"0x3969150.w16.b0", !7008, i64 0}
# !7008 = !{!"0x3969150.w32.b0", !7009, i64 0}
# !7009 = !{!"0x3969150.w64.b0", !7010, i64 0}
# !7010 = !{!"0x3969150.w128.b0", !7011, i64 0}
# !7011 = !{!"0x3969150.w256.b0", !7012, i64 0}
# !7012 = !{!"0x3969150.w512.b0", !7013, i64 0}
# !7013 = !{!"0x3969150.w1024.b0", !7014, i64 0}
# !7014 = !{!"0x3969150", !7, i64 0}
# !7015 = !{!7016, !7016, i64 0}
# !7016 = !{!"0x3969150.w4.b4", !7006, i64 0}
# !7017 = !{!7018, !7018, i64 0}
# !7018 = !{!"0x39cc2c0.w8.b0", !7019, i64 0}
# !7019 = !{!"0x39cc2c0.w16.b0", !7020, i64 0}
# !7020 = !{!"0x39cc2c0.w32.b0", !7021, i64 0}
# !7021 = !{!"0x39cc2c0.w64.b0", !7022, i64 0}
# !7022 = !{!"0x39cc2c0.w128.b0", !7023, i64 0}
# !7023 = !{!"0x39cc2c0.w256.b0", !7024, i64 0}
# !7024 = !{!"0x39cc2c0.w512.b0", !7025, i64 0}
# !7025 = !{!"0x39cc2c0.w1024.b0", !7026, i64 0}
# !7026 = !{!"0x39cc2c0", !7, i64 0}
# !7027 = !{!7028, !7028, i64 0}
# !7028 = !{!"0x4572ce0.w8.b0", !7029, i64 0}
# !7029 = !{!"0x4572ce0.w16.b0", !7030, i64 0}
# !7030 = !{!"0x4572ce0.w32.b0", !7031, i64 0}
# !7031 = !{!"0x4572ce0.w64.b0", !7032, i64 0}
# !7032 = !{!"0x4572ce0.w128.b0", !7033, i64 0}
# !7033 = !{!"0x4572ce0.w256.b0", !7034, i64 0}
# !7034 = !{!"0x4572ce0.w512.b0", !7035, i64 0}
# !7035 = !{!"0x4572ce0.w1024.b0", !7036, i64 0}
# !7036 = !{!"0x4572ce0", !7, i64 0}
# !7037 = !{!7038, !7038, i64 0}
# !7038 = !{!"0x4580dd0.w8.b0", !7039, i64 0}
# !7039 = !{!"0x4580dd0.w16.b0", !7040, i64 0}
# !7040 = !{!"0x4580dd0.w32.b0", !7041, i64 0}
# !7041 = !{!"0x4580dd0.w64.b0", !7042, i64 0}
# !7042 = !{!"0x4580dd0.w128.b0", !7043, i64 0}
# !7043 = !{!"0x4580dd0.w256.b0", !7044, i64 0}
# !7044 = !{!"0x4580dd0.w512.b0", !7045, i64 0}
# !7045 = !{!"0x4580dd0.w1024.b0", !7046, i64 0}
# !7046 = !{!"0x4580dd0", !7, i64 0}
# !7047 = !{!7048, !7048, i64 0}
# !7048 = !{!"0x39b7910.w8.b0", !7049, i64 0}
# !7049 = !{!"0x39b7910.w16.b0", !7050, i64 0}
# !7050 = !{!"0x39b7910.w32.b0", !7051, i64 0}
# !7051 = !{!"0x39b7910.w64.b0", !7052, i64 0}
# !7052 = !{!"0x39b7910.w128.b0", !7053, i64 0}
# !7053 = !{!"0x39b7910.w256.b0", !7054, i64 0}
# !7054 = !{!"0x39b7910.w512.b0", !7055, i64 0}
# !7055 = !{!"0x39b7910.w1024.b0", !7056, i64 0}
# !7056 = !{!"0x39b7910", !7, i64 0}
# !7057 = !{!7058, !7058, i64 0}
# !7058 = !{!"0x3a6ac00", !7, i64 0}
# !7059 = !{!7060, !7060, i64 0}
# !7060 = !{!"0x3a5bae0", !7, i64 0}
# !7061 = !{!7062, !7062, i64 0}
# !7062 = !{!"0x4b4c5c0.w4.b0", !7063, i64 0}
# !7063 = !{!"0x4b4c5c0.w8.b0", !7064, i64 0}
# !7064 = !{!"0x4b4c5c0.w16.b0", !7065, i64 0}
# !7065 = !{!"0x4b4c5c0.w32.b0", !7066, i64 0}
# !7066 = !{!"0x4b4c5c0.w64.b0", !7067, i64 0}
# !7067 = !{!"0x4b4c5c0.w128.b0", !7068, i64 0}
# !7068 = !{!"0x4b4c5c0.w256.b0", !7069, i64 0}
# !7069 = !{!"0x4b4c5c0.w512.b0", !7070, i64 0}
# !7070 = !{!"0x4b4c5c0.w1024.b0", !7071, i64 0}
# !7071 = !{!"0x4b4c5c0", !7, i64 0}
# !7072 = !{!7073, !7073, i64 0}
# !7073 = !{!"0x4b4c5c0.w4.b4", !7063, i64 0}
# !7074 = !{!7075, !7075, i64 0}
# !7075 = !{!"0x4b4fbf0.w8.b0", !7076, i64 0}
# !7076 = !{!"0x4b4fbf0.w16.b0", !7077, i64 0}
# !7077 = !{!"0x4b4fbf0.w32.b0", !7078, i64 0}
# !7078 = !{!"0x4b4fbf0.w64.b0", !7079, i64 0}
# !7079 = !{!"0x4b4fbf0.w128.b0", !7080, i64 0}
# !7080 = !{!"0x4b4fbf0.w256.b0", !7081, i64 0}
# !7081 = !{!"0x4b4fbf0.w512.b0", !7082, i64 0}
# !7082 = !{!"0x4b4fbf0.w1024.b0", !7083, i64 0}
# !7083 = !{!"0x4b4fbf0", !7, i64 0}
# !7084 = !{!7085, !7085, i64 0}
# !7085 = !{!"0x4b4eb70.w8.b0", !7086, i64 0}
# !7086 = !{!"0x4b4eb70.w16.b0", !7087, i64 0}
# !7087 = !{!"0x4b4eb70.w32.b0", !7088, i64 0}
# !7088 = !{!"0x4b4eb70.w64.b0", !7089, i64 0}
# !7089 = !{!"0x4b4eb70.w128.b0", !7090, i64 0}
# !7090 = !{!"0x4b4eb70.w256.b0", !7091, i64 0}
# !7091 = !{!"0x4b4eb70.w512.b0", !7092, i64 0}
# !7092 = !{!"0x4b4eb70.w1024.b0", !7093, i64 0}
# !7093 = !{!"0x4b4eb70", !7, i64 0}
# !7094 = !{!7095, !7095, i64 0}
# !7095 = !{!"0x4b58700.w8.b0", !7096, i64 0}
# !7096 = !{!"0x4b58700.w16.b0", !7097, i64 0}
# !7097 = !{!"0x4b58700.w32.b0", !7098, i64 0}
# !7098 = !{!"0x4b58700.w64.b0", !7099, i64 0}
# !7099 = !{!"0x4b58700.w128.b0", !7100, i64 0}
# !7100 = !{!"0x4b58700.w256.b0", !7101, i64 0}
# !7101 = !{!"0x4b58700.w512.b0", !7102, i64 0}
# !7102 = !{!"0x4b58700.w1024.b0", !7103, i64 0}
# !7103 = !{!"0x4b58700", !7, i64 0}
# !7104 = !{!7105, !7105, i64 0}
# !7105 = !{!"0x4b58bb0.w8.b0", !7106, i64 0}
# !7106 = !{!"0x4b58bb0.w16.b0", !7107, i64 0}
# !7107 = !{!"0x4b58bb0.w32.b0", !7108, i64 0}
# !7108 = !{!"0x4b58bb0.w64.b0", !7109, i64 0}
# !7109 = !{!"0x4b58bb0.w128.b0", !7110, i64 0}
# !7110 = !{!"0x4b58bb0.w256.b0", !7111, i64 0}
# !7111 = !{!"0x4b58bb0.w512.b0", !7112, i64 0}
# !7112 = !{!"0x4b58bb0.w1024.b0", !7113, i64 0}
# !7113 = !{!"0x4b58bb0", !7, i64 0}
# !7114 = !{!7115, !7115, i64 0}
# !7115 = !{!"0x43c5d40", !7, i64 0}
# !7116 = !{!7117, !7117, i64 0}
# !7117 = !{!"0x43be280", !7, i64 0}
# !7118 = !{!7119, !7119, i64 0}
# !7119 = !{!"0x45ec470.w4.b0", !7120, i64 0}
# !7120 = !{!"0x45ec470.w8.b0", !7121, i64 0}
# !7121 = !{!"0x45ec470.w16.b0", !7122, i64 0}
# !7122 = !{!"0x45ec470.w32.b0", !7123, i64 0}
# !7123 = !{!"0x45ec470.w64.b0", !7124, i64 0}
# !7124 = !{!"0x45ec470.w128.b0", !7125, i64 0}
# !7125 = !{!"0x45ec470.w256.b0", !7126, i64 0}
# !7126 = !{!"0x45ec470.w512.b0", !7127, i64 0}
# !7127 = !{!"0x45ec470.w1024.b0", !7128, i64 0}
# !7128 = !{!"0x45ec470", !7, i64 0}
# !7129 = !{!7130, !7130, i64 0}
# !7130 = !{!"0x45ec470.w4.b4", !7120, i64 0}
# !7131 = !{!7132, !7132, i64 0}
# !7132 = !{!"0x45ed290.w8.b0", !7133, i64 0}
# !7133 = !{!"0x45ed290.w16.b0", !7134, i64 0}
# !7134 = !{!"0x45ed290.w32.b0", !7135, i64 0}
# !7135 = !{!"0x45ed290.w64.b0", !7136, i64 0}
# !7136 = !{!"0x45ed290.w128.b0", !7137, i64 0}
# !7137 = !{!"0x45ed290.w256.b0", !7138, i64 0}
# !7138 = !{!"0x45ed290.w512.b0", !7139, i64 0}
# !7139 = !{!"0x45ed290.w1024.b0", !7140, i64 0}
# !7140 = !{!"0x45ed290", !7, i64 0}
# !7141 = !{!7142, !7142, i64 0}
# !7142 = !{!"0x45ddae0.w8.b0", !7143, i64 0}
# !7143 = !{!"0x45ddae0.w16.b0", !7144, i64 0}
# !7144 = !{!"0x45ddae0.w32.b0", !7145, i64 0}
# !7145 = !{!"0x45ddae0.w64.b0", !7146, i64 0}
# !7146 = !{!"0x45ddae0.w128.b0", !7147, i64 0}
# !7147 = !{!"0x45ddae0.w256.b0", !7148, i64 0}
# !7148 = !{!"0x45ddae0.w512.b0", !7149, i64 0}
# !7149 = !{!"0x45ddae0.w1024.b0", !7150, i64 0}
# !7150 = !{!"0x45ddae0", !7, i64 0}
# !7151 = !{!7152, !7152, i64 0}
# !7152 = !{!"0x45dfad0.w8.b0", !7153, i64 0}
# !7153 = !{!"0x45dfad0.w16.b0", !7154, i64 0}
# !7154 = !{!"0x45dfad0.w32.b0", !7155, i64 0}
# !7155 = !{!"0x45dfad0.w64.b0", !7156, i64 0}
# !7156 = !{!"0x45dfad0.w128.b0", !7157, i64 0}
# !7157 = !{!"0x45dfad0.w256.b0", !7158, i64 0}
# !7158 = !{!"0x45dfad0.w512.b0", !7159, i64 0}
# !7159 = !{!"0x45dfad0.w1024.b0", !7160, i64 0}
# !7160 = !{!"0x45dfad0", !7, i64 0}
# !7161 = !{!7162, !7162, i64 0}
# !7162 = !{!"0x45dff80.w8.b0", !7163, i64 0}
# !7163 = !{!"0x45dff80.w16.b0", !7164, i64 0}
# !7164 = !{!"0x45dff80.w32.b0", !7165, i64 0}
# !7165 = !{!"0x45dff80.w64.b0", !7166, i64 0}
# !7166 = !{!"0x45dff80.w128.b0", !7167, i64 0}
# !7167 = !{!"0x45dff80.w256.b0", !7168, i64 0}
# !7168 = !{!"0x45dff80.w512.b0", !7169, i64 0}
# !7169 = !{!"0x45dff80.w1024.b0", !7170, i64 0}
# !7170 = !{!"0x45dff80", !7, i64 0}
# !7171 = !{!7172, !7172, i64 0}
# !7172 = !{!"0x44c9b60", !7, i64 0}
# !7173 = !{!7174, !7174, i64 0}
# !7174 = !{!"0x44c2dc0", !7, i64 0}

# %%
import tvm
from tvm import te

M = 1024
K = 1024
N = 1024

# Algorithm
k = te.reduce_axis((0, K), 'k')
A = te.placeholder((M, K), name='A')
B = te.placeholder((K, N), name='B')
C = te.compute(
           (M, N),
           lambda x, y: te.sum(A[x, k] * B[k, y], axis=k),
           name='C')

# Default schedule
s = te.create_schedule(C.op)
ir_m = tvm.lower(s, [A, B, C], simple_mode=True,name='mmult')
rt_m = tvm.build(ir_m, [A, B, C], target='c', name='mmult')

# print tir
print("tir:\n", ir_m.astext(show_meta_data=False))
# print source code
print("source code:\n",rt_m.get_source())
# Out:
# tir:
#  #[version = "0.0.5"]
# @mmult = primfn(A_1: handle, B_1: handle, C_1: handle) -> ()
#   attr = {"from_legacy_te_schedule": True, "global_symbol": "mmult", "tir.noalias": True}
#   buffers = {A: Buffer(A_2: Pointer(float32), float32, [1048576], []),
#              B: Buffer(B_2: Pointer(float32), float32, [1048576], []),
#              C: Buffer(C_2: Pointer(float32), float32, [1048576], [])}
#   buffer_map = {A_1: A, B_1: B, C_1: C}
#   preflattened_buffer_map = {A_1: A_3: Buffer(A_2, float32, [1024, 1024], []), B_1: B_3: Buffer(B_2, float32, [1024, 1024], []), C_1: C_3: Buffer(C_2, float32, [1024, 1024], [])} {
#   for (x: int32, 0, 1024) {
#     for (y: int32, 0, 1024) {
#       C[((x*1024) + y)] = 0f32
#       for (k: int32, 0, 1024) {
#         let cse_var_2: int32 = (x*1024)
#         let cse_var_1: int32 = (cse_var_2 + y)
#         C[cse_var_1] = (C[cse_var_1] + (A[(cse_var_2 + k)]*B[((k*1024) + y)]))
#       }
#     }
#   }
# }
#
# /* For debugging purposes the metadata section has been omitted.
#  * If you would like to see the full metadata section you can set the
#  * option to `True` when invoking `astext`.
#  */
# source code:
#  // tvm target: c -keys=cpu -link-params=0
# #define TVM_EXPORTS
# #include "tvm/runtime/c_runtime_api.h"
# #include "tvm/runtime/c_backend_api.h"
# #include <math.h>
# #ifdef __cplusplus
# extern "C"
# #endif
# TVM_DLL int32_t mmult(void* args, int32_t* arg_type_ids, int32_t num_args, void* out_ret_value, int32_t* out_ret_tcode, void* resource_handle) {
#   void* arg_A = (((TVMValue*)args)[0].v_handle);
#   int32_t arg_A_code = arg_type_ids[0];
#   void* arg_B = (((TVMValue*)args)[1].v_handle);
#   int32_t arg_B_code = arg_type_ids[1];
#   void* arg_C = (((TVMValue*)args)[2].v_handle);
#   int32_t arg_C_code = arg_type_ids[2];
#   void* A = (((DLTensor*)arg_A)[0].data);
#   void* arg_A_shape = (((DLTensor*)arg_A)[0].shape);
#   void* arg_A_strides = (((DLTensor*)arg_A)[0].strides);
#   int32_t dev_id = (((DLTensor*)arg_A)[0].device.device_id);
#   void* B = (((DLTensor*)arg_B)[0].data);
#   void* arg_B_shape = (((DLTensor*)arg_B)[0].shape);
#   void* arg_B_strides = (((DLTensor*)arg_B)[0].strides);
#   void* C = (((DLTensor*)arg_C)[0].data);
#   void* arg_C_shape = (((DLTensor*)arg_C)[0].shape);
#   void* arg_C_strides = (((DLTensor*)arg_C)[0].strides);
#   if (!(arg_A_strides == NULL)) {
#   }
#   if (!(arg_B_strides == NULL)) {
#   }
#   if (!(arg_C_strides == NULL)) {
#   }
#   for (int32_t x = 0; x < 1024; ++x) {
#     for (int32_t y = 0; y < 1024; ++y) {
#       ((float*)C)[((x * 1024) + y)] = 0.000000e+00f;
#       for (int32_t k = 0; k < 1024; ++k) {
#         int32_t cse_var_2 = (x * 1024);
#         int32_t cse_var_1 = (cse_var_2 + y);
#         ((float*)C)[cse_var_1] = (((float*)C)[cse_var_1] + (((float*)A)[(cse_var_2 + k)] * ((float*)B)[((k * 1024) + y)]));
#       }
#     }
#   }
#   return 0;
# }
#
# // CodegenC: NOTE: Auto-generated entry function
# #ifdef __cplusplus
# extern "C"
# #endif
# TVM_DLL int32_t __tvm_main__(void* args, int* arg_type_ids, int num_args, void* out_ret_value, int* out_ret_tcode, void* resource_handle) {
#   return mmult(args, arg_type_ids, num_args, out_ret_value, out_ret_tcode, resource_handle);
# }
